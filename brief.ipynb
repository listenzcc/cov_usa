# %%
import pandas as pd
import os
import json
from urllib.request import urlopen

# %%
DataDir = os.path.join('.', 'COVIDExposureIndices', 'lex_data')

FileNames = dict()
for prefix in ['county_device', 'county_lex', 'state_lex']:
    FileNames[prefix] = [e for e in os.listdir(DataDir)
                         if e.startswith(prefix)]

# %%
FileNames
# Out:
# {'county_device': ['county_devicescount.csv'],
#  'county_lex': ['county_lex_2020-01-20.csv.gz',
#   'county_lex_2020-01-21.csv.gz',
#   'county_lex_2020-01-22.csv.gz',
#   'county_lex_2020-01-23.csv.gz',
#   'county_lex_2020-01-24.csv.gz',
#   'county_lex_2020-01-25.csv.gz',
#   'county_lex_2020-01-26.csv.gz',
#   'county_lex_2020-01-27.csv.gz',
#   'county_lex_2020-01-28.csv.gz',
#   'county_lex_2020-01-29.csv.gz',
#   'county_lex_2020-01-30.csv.gz',
#   'county_lex_2020-01-31.csv.gz',
#   'county_lex_2020-02-01.csv.gz',
#   'county_lex_2020-02-02.csv.gz',
#   'county_lex_2020-02-03.csv.gz',
#   'county_lex_2020-02-04.csv.gz',
#   'county_lex_2020-02-05.csv.gz',
#   'county_lex_2020-02-06.csv.gz',
#   'county_lex_2020-02-07.csv.gz',
#   'county_lex_2020-02-08.csv.gz',
#   'county_lex_2020-02-09.csv.gz',
#   'county_lex_2020-02-10.csv.gz',
#   'county_lex_2020-02-11.csv.gz',
#   'county_lex_2020-02-12.csv.gz',
#   'county_lex_2020-02-13.csv.gz',
#   'county_lex_2020-02-14.csv.gz',
# ...

# %%
df = pd.read_csv(os.path.join(DataDir, FileNames['county_lex'][-1]))
df
# Out:
#       COUNTY_PRE     01001     01003     01005     01007     01009     01013  \
# 0           1001  0.917964  0.007148  0.013188  0.058841  0.008422  0.074327
# 1           1003  0.025644  0.958653  0.012529  0.017683  0.006576  0.067920
# 2           1005  0.006280  0.001053  0.867788  0.002439  0.000923  0.009825
# 3           1007  0.019626  0.001204  0.002638  0.894817  0.008768  0.005553
# 4           1009  0.006804  0.002182  0.002967  0.020732  0.923281  0.004699
# ...          ...       ...       ...       ...       ...       ...       ...
# 2013       56029  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2014       56033  0.000000  0.000000  0.000330  0.000000  0.000000  0.000000
# 2015       56037  0.000654  0.000376  0.000659  0.000000  0.000115  0.000000
# 2016       56039  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2017       56041  0.000262  0.000188  0.000330  0.000000  0.000000  0.000000
#
# ...

# %%
import plotly.figure_factory as ff

fips = ['06021', '06023', '06027',
        '06029', '06033', '06059',
        '06047', '06049', '06051',
        '06055', '06061']
values = range(len(fips))

fig = ff.create_choropleth(fips=fips, values=values)
fig.layout.template = None
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f27641beeb78> in <module>
#       7 values = range(len(fips))
#       8
# ----> 9 fig = ff.create_choropleth(fips=fips, values=values)
#      10 fig.layout.template = None
#      11 fig.show()
#
# ~\Anaconda3\lib\site-packages\plotly\figure_factory\_county_choropleth.py in create_choropleth(fips, values, scope, binning_endpoints, colorscale, order, simplify_county, simplify_state, asp, show_hover, show_state_data, state_outline, county_outline, centroid_marker, round_legend_values, exponent_format, legend_title, **layout_options)
#     625     if not gp or not shapefile or not shapely:
#     626         raise ImportError(
# --> 627             "geopandas, pyshp and shapely must be installed for this figure "
#     628             "factory.\n\nRun the following commands to install the correct "
# ...
